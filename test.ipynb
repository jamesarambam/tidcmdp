# %%
import mdptoolbox.example as m
import numpy as np

# %%
a = np.random.rand(2, 2, 3, 3, 2, 2)

# %%
a.shape
# Out:
# (2, 2, 3, 3, 2, 2)

# %%
a
# Out:
# array([[[[[[ 0.40652135,  0.80772549],
#            [ 0.81570656,  0.26884083]],
#
#           [[ 0.94151673,  0.18974732],
#            [ 0.20802408,  0.40880366]],
#
#           [[ 0.48760942,  0.37005671],
#            [ 0.92421415,  0.09774657]]],
#
#
#          [[[ 0.50004302,  0.87093341],
#            [ 0.40596008,  0.11142139]],
#
#           [[ 0.89887387,  0.25327559],
#            [ 0.07939099,  0.73383563]],
#
#           [[ 0.63848128,  0.15833482],
#            [ 0.37499697,  0.63287032]]],
#
#
#          [[[ 0.25617455,  0.07418032],
#            [ 0.329878  ,  0.93309816]],
#
#           [[ 0.50106626,  0.01981722],
#            [ 0.59860205,  0.0939537 ]],
#
#           [[ 0.48622567,  0.059981  ],
#            [ 0.10076452,  0.96340817]]]],
#
#
#
#         [[[[ 0.03633341,  0.58728571],
#            [ 0.35494413,  0.73879571]],
#
#           [[ 0.72136493,  0.40541285],
#            [ 0.64563033,  0.93409307]],
#
#           [[ 0.11125229,  0.64883289],
# ...
